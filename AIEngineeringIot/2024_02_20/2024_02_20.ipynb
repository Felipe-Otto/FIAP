# %% [markdown]
# Im´potando

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
image_bgr = cv2.imread('/content/images/Folha.jpg')
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)
plt.axis('off')
plt.imshow(image_rgb)

# %%
r, g, b = cv2.split(image_rgb)
plt.imshow(r, cmap='gray')
plt.show()
plt.imshow(g, cmap='gray')
plt.show()
plt.imshow(b, cmap='gray')
plt.show()
plt.imshow(b)

# %% [markdown]
# Convertendo a imagem em escala cinza

# %%
num_rows, num_columns = image_rgb.shape[0], image_rgb.shape[1]

# Criando uma matriz
image_gray = np.zeros((num_rows, num_columns))

'''
for rows in range (num_rows):
  for columns in range (num_columns):
      (r, g, b) = image_rgb[num_rows, num_columns]
      image_gray[num_rows, num_columns] = (r + g + b)/3
plt.imshow(image_gray, cmap='gray')
''' # <- NEsse conseguimos manipular! (Obs: esse cod está errado)

image_gray = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)
plt.imshow(image_gray, cmap='gray')

# %%
image_satellite = cv2.imread('/content/images/satelite.jpg')
image_satellite = cv2.cvtColor(image_satellite, cv2.COLOR_BGR2RGB)
r, g, b = cv2.split(image_satellite)
plt.imshow(r)

# Variações do cmap
plot_color_gradients = ['viridis', 'plasma', 'inferno', 'magma', 'cividis']
for plot in plot_color_gradients:
  plt.imshow(r, cmap=plot)
  plt.show()
# plt.colorbar() <- printa com uma barra de escala das cores da imagem

# %%
# Invertendo os canais de cores (negativo)
image_flower = cv2.imread('/content/images/Flor.jpg')
image_flower = cv2.cvtColor(image_flower, cv2.COLOR_BGR2RGB)
plt.imshow(image_flower)
plt.show()
image_flower_saturation = image_flower.max() - image_flower
plt.imshow(image_flower_saturation, cmap='gray')
'''
# Desafio:

image_toad = cv2.imread('/content/images/cogumelo.png')
image_toad = cv2.cvtColor(image_toad, cv2.COLOR_BGR2RGB)
plt.imshow(image_toad)
plt.show()
image_toad_saturation = image_toad.max() - image_toad
plt.imshow(image_toad_saturation, cmap='gray')

image_toad = cv2.imread('/content/images/cogumelo.png')
image_toad = cv2.cvtColor(image_toad, cv2.COLOR_BGR2RGB)

for column in range(0, image.shape[0]):
  for row in range(0, image.shape[1]):

# OU

image_toad = cv2.imread('/content/images/cogumelo.png')
image_toad = cv2.cvtColor(image_toad, cv2.COLOR_BGR2RGB)

for column in range(0, image_toad.shape[0]):
  for row in range(0, image_toad.shape[1]):
      image_toad[column, row] = 0 if image_toad[column, row] == 255 else 255 # Tem erro aqui

plt.imshow(image_toad)
'''

# %% [markdown]
# CP!??

# %%
image_drone = cv2.imread('/content/images/drone.jpg')
image_drone = cv2.cvtColor(image_drone, cv2.COLOR_BGR2RGB)
plt.imshow(image_drone)
plt.show()
# DEixar os eixos na imagem, pois será necessário!

#        corte_image[y:y+h,  x, x+w] <- corrdenadas de onde o dorne está
image_drone_focus = image_drone[50:250, 550:1000]
plt.imshow(image_drone_focus)
plt.show()
image_sun_focus = image_drone[225:270, 590:640]
plt.imshow(image_sun_focus)
plt.show()

# %% [markdown]
# Arrumando os quadrantes da imagem

# %%
image_goku = cv2.imread('/content/images/gokuinvertido.jpg')
image_goku = cv2.cvtColor(image_goku, cv2.COLOR_BGR2RGB)
height = image_goku.shape[0]
width = image_goku.shape[1]
plt.imshow(image_goku)
plt.show()
Q1 = image_goku[int(height/2):height, int(width/2):width]
Q2 = image_goku[int(height/2):height, 0:int(width/2)]
Q3 = image_goku[0:int(height/2), int(width/2):width]
Q4 = image_goku[0:int(height/2), 0:int(width/2)]
image_goku_right = image_goku.copy()
image_goku_right[0:int(height/2), int(width/2):width] = Q2
image_goku_right[0:int(height/2), 0:int(width/2)] = Q1
image_goku_right[int(height/2):height, int(width/2):width] = Q4
image_goku_right[int(height/2):height, 0:int(width/2)] = Q3
plt.imshow(image_goku_right)
plt.show()

# %% [markdown]
# Gruta

# %%
image_drone = cv2.imread('/content/images/drone.jpg')
image_drone = cv2.cvtColor(image_drone, cv2.COLOR_BGR2RGB)
plt.imshow(image_drone)
plt.show()
for column in range(0, image_drone.shape[0]):
  for row in range(0, image_drone.shape[1]):
    if image_drone[column, row, 0] > 60: # O 0 é camada
      image_drone[column, row] = (255,255,255)

  plt.imshow(image_drone)
# Out:
# Error in callback <function _draw_all_if_interactive at 0x7ecfb1224ee0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in _draw_all_if_interactive()
#     118 def _draw_all_if_interactive():
#     119     if matplotlib.is_interactive():
# --> 120         draw_all()
#     121
#     122
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     130         for manager in cls.get_all_fig_managers():
#     131             if force or manager.canvas.figure.stale:
# --> 132                 manager.canvas.draw_idle()
#     133
#     134
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2080         if not self._is_idle_drawing:
#    2081             with self._idle_draw_cntx():
# ...

# %%
image_ball = cv2.imread('/content/images/Capture.png')
image_ball = cv2.cvtColor(image_ball, cv2.COLOR_BGR2RGB)
plt.imshow(image_ball)
plt.show()
for column in range(0, image_ball.shape[0]):
  for row in range(0, image_ball.shape[1]):
    if image_ball[column, row, 0] < 250:
      image_ball[column, row] = (0, 0, 0)
    else:
      image_ball[column, row] = (255, 255, 255)
plt.imshow(image_ball)
plt.show()
